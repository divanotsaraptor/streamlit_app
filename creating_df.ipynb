# %%
import pandas as pd
import numpy as np

df = pd.read_csv('C:/Users/Danya/Downloads/train_data/realty_data.csv')
df['district_cat'] = df['district'].astype('category')
df['city_cat']=df['city'].astype('category')

unique_districts = pd.DataFrame(df['district_cat'].unique(), columns=['district_cat'])
pd.DataFrame(df['city_cat'].unique(),columns=['city_cat']).to_csv('city_df.csv', index=False, encoding='utf-8')

unique_districts.to_csv('district_df.csv', index=False, encoding='utf-8')
